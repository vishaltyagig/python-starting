# %% [markdown]
# # A Quiz Game in Python

# %%
questions = ("How many elements are in the periodic table?: ", 
             "Which animal Lays the largest eggs?: ", 
             "What is the most aboduent gas in the Earth's atmosphere?: ", 
             "How many bones are in the human body:? ", 
             "Which planet is hotest in the solar system?: ",)

options = (("A. 116", "B. 117", "C. 118", "D. 119"),
           ("A. Whele", "B.Crocodile ", "C. Elephant", "D. Ostrich"),
           ("A. Nitrogen", "B. Oxygen", "C. Carbon- diaoxide", "D. Hydrogen"),
           ("A. 206", "B. 207", "C. 208", "D. 209"),
           ("A. Mercury", "B. Venus", "C. Earth", "D. Mars"))

answers = ("C", "D", "A", "A", "B")

guesses = []

score = 0

question_num = 0

for question in questions:
    print("----------------------")
    print(question)
# Out:
# ----------------------
# How many elements are in the periodic table?:
# ----------------------
# Which animal Lays the largest eggs?:
# ----------------------
# What is the most aboduent gas in the Earth's atmosphere?:
# ----------------------
# How many bones are in the human body:?
# ----------------------
# Which planet is hotest in the solar system?:

# %%
questions = ("How many elements are in the periodic table?: ", 
             "Which animal Lays the largest eggs?: ", 
             "What is the most aboduent gas in the Earth's atmosphere?: ", 
             "How many bones are in the human body:? ", 
             "Which planet is hotest in the solar system?: ",)

options = (("A. 116", "B. 117", "C. 118", "D. 119"),
           ("A. Whele", "B.Crocodile ", "C. Elephant", "D. Ostrich"),
           ("A. Nitrogen", "B. Oxygen", "C. Carbon- diaoxide", "D. Hydrogen"),
           ("A. 206", "B. 207", "C. 208", "D. 209"),
           ("A. Mercury", "B. Venus", "C. Earth", "D. Mars"))

answers = ("C", "D", "A", "A", "B")

guesses = []

score = 0

question_num = 0

for question in questions:
    print("----------------------")
    print(question)
    for option in options[question_num]:
        print(option)
# Out:
# ----------------------
# How many elements are in the periodic table?:
# A. 116
# B. 117
# C. 118
# D. 119
# ----------------------
# Which animal Lays the largest eggs?:
# A. 116
# B. 117
# C. 118
# D. 119
# ----------------------
# What is the most aboduent gas in the Earth's atmosphere?:
# A. 116
# B. 117
# C. 118
# D. 119
# ----------------------
# How many bones are in the human body:?
# A. 116
# B. 117
# C. 118
# D. 119
# ----------------------
# Which planet is hotest in the solar system?:
# A. 116
# B. 117
# C. 118
# D. 119

# %%
questions = ("How many elements are in the periodic table?: ", 
             "Which animal Lays the largest eggs?: ", 
             "What is the most aboduent gas in the Earth's atmosphere?: ", 
             "How many bones are in the human body:? ", 
             "Which planet is hotest in the solar system?: ",)

options = (("A. 116", "B. 117", "C. 118", "D. 119"),
           ("A. Whele", "B.Crocodile ", "C. Elephant", "D. Ostrich"),
           ("A. Nitrogen", "B. Oxygen", "C. Carbon- diaoxide", "D. Hydrogen"),
           ("A. 206", "B. 207", "C. 208", "D. 209"),
           ("A. Mercury", "B. Venus", "C. Earth", "D. Mars"))

answers = ("C", "D", "A", "A", "B")

guesses = []

score = 0

question_num = 0

for question in questions:
    print("----------------------")
    print(question)
    for option in options[question_num]:
        print(option)
        
    guess = input("Enter (A, B, C, D): ").upper()
    guesses.append(guess)
    if guess == answers[question_num]:
        score += 1
        print("CORRECT!")
    else:
        print("INCORRECT!")
        print(f"{answers[question_num]} is the corrct answer")
    question_num += 1
# Out:
# ----------------------
# How many elements are in the periodic table?:
# A. 116
# B. 117
# C. 118
# D. 119
# Enter (A, B, C, D): a
# INCORRECT!
# C is the corrct answer
# ----------------------
# Which animal Lays the largest eggs?:
# A. Whele
# B.Crocodile
# C. Elephant
# D. Ostrich
# Enter (A, B, C, D): f
# INCORRECT!
# D is the corrct answer
# ----------------------
# What is the most aboduent gas in the Earth's atmosphere?:
# A. Nitrogen
# B. Oxygen
# C. Carbon- diaoxide
# D. Hydrogen
# Enter (A, B, C, D): b
# INCORRECT!
# A is the corrct answer
# ----------------------
# How many bones are in the human body:?
# A. 206
# B. 207
# C. 208
# D. 209
# Enter (A, B, C, D): a
# CORRECT!
# ----------------------
# Which planet is hotest in the solar system?:
# A. Mercury
# B. Venus
# C. Earth
# D. Mars
# Enter (A, B, C, D): b
# CORRECT!

# %%
questions = ("How many elements are in the periodic table?: ", 
             "Which animal Lays the largest eggs?: ", 
             "What is the most aboduent gas in the Earth's atmosphere?: ", 
             "How many bones are in the human body:? ", 
             "Which planet is hotest in the solar system?: ",)

options = (("A. 116", "B. 117", "C. 118", "D. 119"),
           ("A. Whele", "B.Crocodile ", "C. Elephant", "D. Ostrich"),
           ("A. Nitrogen", "B. Oxygen", "C. Carbon- diaoxide", "D. Hydrogen"),
           ("A. 206", "B. 207", "C. 208", "D. 209"),
           ("A. Mercury", "B. Venus", "C. Earth", "D. Mars"))

answers = ("C", "D", "A", "A", "B")

guesses = []

score = 0

question_num = 0

for question in questions:
    print("----------------------")
    print(question)
    for option in options[question_num]:
        print(option)
        
    guess = input("Enter (A, B, C, D): ").upper()
    guesses.append(guess)
    if guess == answers[question_num]:
        score += 1
        print("CORRECT!")
    else:
        print("INCORRECT!")
        print(f"{answers[question_num]} is the corrct answer")
    question_num += 1
    
print("----------------------")
print("        Result        ")
print("----------------------")

print("answers: ", end="")
for answer in answers:
    print(answer, end=" ")
print()

print("guesses: ", end="")
for guess in guesses:
    print(guess, end=" ")
print()
# Out:
# ----------------------
# How many elements are in the periodic table?:
# A. 116
# B. 117
# C. 118
# D. 119
# Enter (A, B, C, D): a
# INCORRECT!
# C is the corrct answer
# ----------------------
# Which animal Lays the largest eggs?:
# A. Whele
# B.Crocodile
# C. Elephant
# D. Ostrich
# Enter (A, B, C, D): a
# INCORRECT!
# D is the corrct answer
# ----------------------
# What is the most aboduent gas in the Earth's atmosphere?:
# A. Nitrogen
# B. Oxygen
# C. Carbon- diaoxide
# D. Hydrogen
# Enter (A, B, C, D): c
# INCORRECT!
# A is the corrct answer
# ----------------------
# How many bones are in the human body:?
# A. 206
# B. 207
# C. 208
# D. 209
# Enter (A, B, C, D): a
# CORRECT!
# ----------------------
# Which planet is hotest in the solar system?:
# A. Mercury
# B. Venus
# C. Earth
# D. Mars
# Enter (A, B, C, D): b
# CORRECT!
# ----------------------
#         Result
# ----------------------
# answers: C D A A B
# guesses: A A C A B

# %%
questions = ("How many elements are in the periodic table?: ", 
             "Which animal Lays the largest eggs?: ", 
             "What is the most aboduent gas in the Earth's atmosphere?: ", 
             "How many bones are in the human body:? ", 
             "Which planet is hotest in the solar system?: ",)

options = (("A. 116", "B. 117", "C. 118", "D. 119"),
           ("A. Whele", "B.Crocodile ", "C. Elephant", "D. Ostrich"),
           ("A. Nitrogen", "B. Oxygen", "C. Carbon- diaoxide", "D. Hydrogen"),
           ("A. 206", "B. 207", "C. 208", "D. 209"),
           ("A. Mercury", "B. Venus", "C. Earth", "D. Mars"))

answers = ("C", "D", "A", "A", "B")

guesses = []

score = 0

question_num = 0

for question in questions:
    print("----------------------")
    print(question)
    for option in options[question_num]:
        print(option)
        
    guess = input("Enter (A, B, C, D): ").upper()
    guesses.append(guess)
    if guess == answers[question_num]:
        score += 1
        print("CORRECT!")
    else:
        print("INCORRECT!")
        print(f"{answers[question_num]} is the corrct answer")
    question_num += 1
    
print("----------------------")
print("        Result        ")
print("----------------------")

print("answers: ", end="")
for answer in answers:
    print(answer, end=" ")
print()

print("guesses: ", end="")
for guess in guesses:
    print(guess, end=" ")
print()

score = int(score / len(questions) * 100)
print(f"your score is: {score}%")
# Out:
# ----------------------
# How many elements are in the periodic table?:
# A. 116
# B. 117
# C. 118
# D. 119
# Enter (A, B, C, D): c
# CORRECT!
# ----------------------
# Which animal Lays the largest eggs?:
# A. Whele
# B.Crocodile
# C. Elephant
# D. Ostrich
# Enter (A, B, C, D): d
# CORRECT!
# ----------------------
# What is the most aboduent gas in the Earth's atmosphere?:
# A. Nitrogen
# B. Oxygen
# C. Carbon- diaoxide
# D. Hydrogen
# Enter (A, B, C, D): a
# CORRECT!
# ----------------------
# How many bones are in the human body:?
# A. 206
# B. 207
# C. 208
# D. 209
# Enter (A, B, C, D): a
# CORRECT!
# ----------------------
# Which planet is hotest in the solar system?:
# A. Mercury
# B. Venus
# C. Earth
# D. Mars
# Enter (A, B, C, D): b
# CORRECT!
# ----------------------
#         Result
# ----------------------
# answers: C D A A B
# guesses: C D A A B
# your score is: 100%
